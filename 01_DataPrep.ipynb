# %% [markdown]
# # Data Prep

# %% [markdown]
# The goal of this notebook is to prep the data for the alignment task.  This includes generating noisy data and extracting CENS features.

# %%
import numpy as np
import librosa as lb
import os
import os.path
from pathlib import Path
import multiprocessing

# %%
ANNOTATIONS_ROOT = Path('Chopin_Mazurkas/annotations_beat')
AUDIO_ROOT = Path('Chopin_Mazurkas/wav_22050_mono')
FEATURES_ROOT = Path('features')
train_files = Path('cfg_files/filelist.train.txt')
test_files = Path('cfg_files/filelist.test.txt')

# %%
if not os.path.exists(FEATURES_ROOT):
    os.mkdir(FEATURES_ROOT)

# %% [markdown]
# ### Compute features on clean audio

# %% [markdown]
# First we compute features on the original audio.

# %%
def compute_chroma_single(infile, outfile, sr = 22050, hop_length=512):
    y, sr = lb.core.load(infile, sr = sr)
    #F = lb.feature.chroma_cens(y, sr=sr, hop_length=hop_length)
    F = lb.feature.chroma_cqt(y, sr=sr, hop_length=hop_length, norm=2)
    np.save(outfile, F)
    return

# %%
def compute_chroma_batch(filelist, outdir, n_cores):
    
    # prep inputs for parallelization
    inputs = []
    with open(filelist, 'r') as f:
        for line in f:
            relpath = line.strip()
            reldir, fileid = os.path.split(relpath)
            featdir = outdir / reldir
            featdir.mkdir(parents=True, exist_ok=True)
            featfile = (featdir / fileid).with_suffix('.npy')
            audiofile = (AUDIO_ROOT / relpath).with_suffix('.wav')
            if os.path.exists(featfile):
                print(f"Skipping {featfile}")
            else:
                inputs.append((audiofile, featfile))

    # process files in parallel
    pool = multiprocessing.Pool(processes = n_cores)
    pool.starmap(compute_chroma_single, inputs)
    
    return

# %%
FEATS_CLEAN_DIR = FEATURES_ROOT / 'clean'
compute_chroma_batch(train_files, FEATS_CLEAN_DIR, 24)
compute_chroma_batch(test_files, FEATS_CLEAN_DIR, 24)
# Out:
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Afanassiev-2001_pid9130-01.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Ashkenazy-1981_pid9058-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Beliavsky-2004_pid9152-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Ben-Or-1989_pid9161-12.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Biret-1990_pid9062-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Blet-2003_pid9103-07.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Block-1995_pid9064-04.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Brailowsky-1960_pid9060-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Chiu-1999_pid9048-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Clidat-1994_pid9067-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Cohen-1997_pid9105-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Coop-1987_pid9159-04.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Cortot-1951_pid9066-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Czerny-Stefanska-1949_pid9085-15.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Czerny-Stefanska-1949_pid9086-07.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Ezaki-2006_pid9139-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Falvay-1989_pid9068-08.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Ferenczy-1958_pid9097-17.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Fiorentino-1990_pid9065-08.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Fliere-1977_pid9063-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Fou-1978_pid9071-20.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Francois-1956_pid9070-21.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Hatto-2006_pid9073-15.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Horowitz-1971_pid59340c-06.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Horowitz-1985_pid50534-05.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Indjic-1988_pid9050-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Kapell-1951_pid9090-06.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Kiepura-1999_pid9098-20.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Kilenyi-1937_pid9164-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Kissin-1993_pid9056-15.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Kitain-1937_pid9163-02.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Kushner-1990_pid9118-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Levy-1951_pid915406-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Luisada-1990_pid9055-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Lushtak-2004_pid9088-08.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Lympany-1968_pid9160-02.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Magaloff-1977_pid5667267b-10.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Magaloff-1977_pid9074f-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Magin-1975_pid9138-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Milkina-1970_pid9099-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Mohovich-1999_pid9104-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Nadelmann-1956_pid9165-04.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Ohlsson-1999_pid9153-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Olejniczac-1990_pid9100b-17.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Olejniczak-1991_pid9087-07.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Osinska-1989_pid9101-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Paderewski-1912_pid5667274-09.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Perahia-1994_pid54293-09.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Perlemuter-1986_pid9089-15.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Poblocka-1999_pid9093-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Rangell-2001_pid9094-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Risler-1920_pid9132-11.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Rosen-1989_pid52932-06.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Rubinstein-1939_pid9049-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Rubinstein-1952_pid9075-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Rubinstein-1966_pid9059-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Rummel-1943_pid54851-12.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Shebanova-2002_pid9072-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Smith-1975_pid9054-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Szpilman-1948_pid9147-12.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Uninsky-1971_pid9061-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Wasowski-1980_pid9111-13.npy
# Skipping features/clean/Chopin_Op017No4/Chopin_Op017No4_Weissenberg-1971_pid9052b-09.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Ashkenazy-1981_pid9058-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Ax-1985_pid9179-07.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Bacha-1998_pid9166e-08.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Barbosa-1983_pid9174-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Ben-Or-1989_pid9161-13.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Biret-1990_pid9062-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Brailowsky-1960_pid9060-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Chiu-1999_pid9048-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Clidat-1994_pid9067-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Cohen-1997_pid9105-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Cortot-1951_pid9066-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Csalog-1996_pid1263-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Czerny-Stefanska-1989_pid9192-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Ezaki-2006_pid9139-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Falvay-1989_pid9068-10.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Fiorentino-1961_pid9065-10.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Fliere-1977_pid9063-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Fou-1978_pid9071-26.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Francois-1956_pid9070-23.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Goldenweiser-1946_pid917509-04.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Gornostaeva-1994_pid9116-06.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Groot-1988_pid9198g-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Hatto-1993_pid610003-17.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Hatto-2006_pid9073-17.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Horszowski-1983_pid9131-12.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Indjic-1988_pid9050-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Katin-1996_pid9126-03.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Kiepura-1999_pid9098-02.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Korecka-Soszkowska-1992_pid9128-11.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Kushner-1990_pid9118-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Lilamand-2001_pid9186c-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Luisada-1990_pid9055-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Luisada-2008_pid610242-01.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Lushtak-2004_pid9088-10.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Magaloff-1977_pid9074f-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Magin-1975_pid9138-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Malcuzynski-1951_pid9091-22.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Malcuzynski-1961_pid918904-03.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Meguri-1997_pid9137-09.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Milkina-1970_pid9099-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Mohovich-1999_pid9104-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Nezu-2005_pid9081-03.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Ohlsson-1999_pid9153-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Olejniczac-1990_pid9100b-11.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Osinska-1989_pid9101-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Perlemuter-1992_pid9089-08.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Poblocka-1999_pid9093-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Rangell-2001_pid9094-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Richter-1960_pid915410b-22.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Richter-1961_pid918722-04.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Rosen-1989_pid52932-08.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Rubinstein-1939_pid9049-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Rubinstein-1952_pid9075-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Rubinstein-1966_pid9059-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Rudanovskaya-2007_pid610242-02.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Shebanova-2002_pid9072-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Smith-1975_pid9054-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Sztompka-1959_pid9170-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Tanyel-1992_pid917813-03.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Tsujii-2005_pid9078-07.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Uninsky-1959_pid9061-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Vardi-1988_pid9173-20.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Wasowski-1980_pid9111-15.npy
# Skipping features/clean/Chopin_Op024No2/Chopin_Op024No2_Zimerman-1975_pid6100021-11.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Ashkenazy-1981_pid9058-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Ashkenazy-1982_pid50848-03.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Biret-1990_pid9062-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Blet-2003_pid9103-10.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Brailowsky-1960_pid9060-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Chiu-1999_pid9048-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Clidat-1994_pid9067-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Cortot-1951_pid9066-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Ferenczy-1956_pid9097-04.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Fiorentino-1961_pid9065-14.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Fliere-1977_pid9063-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Fou-1978_pid9071-30.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Fou-2005_pid9092-13.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Francois-1956_pid9070b-02.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Hatto-2006_pid9073-21.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Indjic-1988_pid9050-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Jonas-1947_pid9096-07.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Luisada-1990_pid9055-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Lushtak-2004_pid9088-14.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Magaloff-1977_pid9074f-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Michelangeli-1971_pid5667269b-38.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Milkina-1970_pid9099-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Mohovich-1999_pid9104-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Olejniczac-1990_pid9100b-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Poblocka-1999_pid9093-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Rangell-2001_pid9094-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Rubinstein-1939_pid9049-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Rubinstein-1952_pid9075-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Rubinstein-1966_pid9059-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Shebanova-2002_pid9072-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Smith-1975_pid9054-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Sofronitsky-1960_pid5667291-15.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Uninsky-1959_pid9061-19.npy
# Skipping features/clean/Chopin_Op030No2/Chopin_Op030No2_Yaroshinskiy-2005_pid9081-10.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Afanassiev-2001_pid9130-11.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Anderszewski-2003_pid58917-06.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Ashkenazy-1981_pid9058b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Bacha-2000_pid9166l-10.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Badura-Skoda-1965_pid915412b-21.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Barbosa-1983_pid9174b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Biret-1990_pid9062b-15.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Blet-2003_pid9103-20.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Block-1995_pid9064-21.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Blumental-1952_pid9102-07.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Boshniakovich-1969_pid9127-06.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Brailowsky-1960_pid9060b-10.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Bunin-1987_pid9124-13.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Bunin-1987_pid918812-13.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Chiu-1999_pid9048b-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Cohen-1997_pid9069-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Cortot-1951_pid9066b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Csalog-1996_pid1263b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Czerny-Stefanska-1949_pid9085-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Czerny-Stefanska-1990_pid9192b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Duchoud-2007_pid610633-01.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Ezaki-2006_pid9139b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Falvay-1989_pid9068-20.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Farrell-1958_pid918805-02.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Ferenczy-1958_pid9097-24.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Fliere-1977_pid9063b-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Fou-1978_pid9071b-22.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Francois-1956_pid9070b-24.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Friedman-1923_pid9108-02.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Friedman-1923_pid9148-15.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Friedman-1930_pid5667230-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Garcia-Casas_pid610633-02.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Garcia-Casas_pid610633-07.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Gierzod-1998_pid9121-07.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Gornostaeva-1994_pid9116-20.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Groot-1988_pid9198h-18.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Harasiewicz-1955_pid9086-13.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Hatto-1993_pid610003b-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Hatto-2006_pid9073b-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Horowitz-1949_pid5667249-22.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Indjic-1988_pid9050b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Kapell-1951_pid9090-21.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Kissin-1993_pid9056-07.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Kushner-1989_pid9118b-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Luisada-1991_pid9055b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Lushtak-2004_pid9088-22.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Magaloff-1978_pid9074g-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Magin-1975_pid9138b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Malcuzynski-1961_pid918904-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Michalowski-1933_pid9083-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Milkina-1970_pid9099b-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Mohovich-1999_pid9104b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Moravec-1969_pid5667271-05.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Morozova-2008_pid610633-04.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Neighaus-1950_pid9119-14.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Niedzielski-1931_pid919401-03.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Ohlsson-1999_pid9153b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Osinska-1989_pid9101c-06.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Pachmann-1927_pid9110-09.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Paderewski-1930_pid5667274b-06.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Perlemuter-1992_pid9089-07.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Pierdomenico-2008_pid610633-03.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Poblocka-1999_pid9093b-18.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rabcewiczowa-1932_pid9091-15.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rachmaninoff-1923_pid9095-11.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rangell-2001_pid9094b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Richter-1976_pid9172-10.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rosen-1989_pid52932-24.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rosenthal-1930_pid9183-05.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rosenthal-1931_pid9057j-07.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rosenthal-1931_pid9141-09.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rosenthal-1931_pid9183-11.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rosenthal-1931_pid9183-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rossi-2007_pid610633-05.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rubinstein-1939_pid9049b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rubinstein-1952_pid9075b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Rubinstein-1966_pid9059b-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Schilhawsky-1960_pid9129-17.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Shebanova-2002_pid9072b-16.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Smith-1975_pid9054b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Sokolov-2002_pid610633-06.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Sztompka-1959_pid9170b-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Tomsic-1995_pid9190-09.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Uninsky-1932_pid9085-11.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Uninsky-1971_pid9061b-09.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Wasowski-1980_pid9111b-14.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Zak-1937_pid9085-12.npy
# Skipping features/clean/Chopin_Op063No3/Chopin_Op063No3_Zak-1951_pid918713-20.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Ashkenazy-1981_pid9058b-19.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Bacha-1997_pid9166b-09.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Barbosa-1983_pid9174b-19.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Biret-1990_pid9062b-22.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Block-1995_pid9064-02.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Brailowsky-1960_pid9060b-17.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Chiu-1999_pid9048b-22.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Clidat-1994_pid9067-27.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Cohen-1997_pid9069-19.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Cortot-1951_pid9066b-19.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Csalog-1996_pid1263b-19.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Czerny-Stefanska-1990_pid9192b-21.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Ezaki-2006_pid9139b-21.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Ferenczy-1958_pid9097-15.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Fliere-1977_pid9063b-25.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Fou-1978_pid9071-04.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Francois-1956_pid9070b-31.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Grinberg-1951_pid9112-11.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Hatto-1993_pid610003b-23.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Hatto-2006_pid9073b-25.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Indjic-1988_pid9050b-21.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Jonas-1947_pid9096-03.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Kapell-1951_pid9090-26.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Kiepura-1999_pid9098-07.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Kushner-1989_pid9118b-25.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Luisada-1991_pid9055b-19.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Lushtak-2004_pid9088-25.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Magaloff-1978_pid9074g-19.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Meguri-1997_pid9137-22.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Milkina-1970_pid9099b-25.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Mohovich-1999_pid9104b-19.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Niedzielski-1931_pid919401-04.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Ohlsson-1999_pid9153b-21.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Olejniczac-1990_pid9100b-08.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Osinska-1989_pid9101c-15.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Rangell-2001_pid9094b-27.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Richter-1976_pid9172-12.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Rubinstein-1939_pid9049b-19.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Rubinstein-1952_pid9075b-19.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Rubinstein-1966_pid9059b-23.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Shebanova-2002_pid9072b-23.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Smidowicz-1948_pid9082-11.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Smidowicz-1948_pid9091-17.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Smith-1975_pid9054b-21.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Sofronitsky-1949_pid9114-34.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Sztompka-1959_pid9170b-21.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Tomsic-1995_pid9190-11.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Uninsky-1971_pid9061b-16.npy
# Skipping features/clean/Chopin_Op068No3/Chopin_Op068No3_Wasowski-1980_pid9111b-21.npy

# %% [markdown]
# ### Compute features on noisy audio (AWGN)

# %% [markdown]
# Now we compute chroma features on the audio with additive white gaussian noise at specified SNR levels.

# %%
def compute_chroma_AWGN_single(infile, outfile, snr_db, sr = 22050, hop_length=512):
    y, sr = lb.core.load(infile, sr = sr)
    noise_power = np.mean(y*y) * np.power(10, -1*snr_db/10)
    noise = np.random.randn(len(y)) * np.sqrt(noise_power)
    y_noisy = y + noise
    #F = lb.feature.chroma_cens(y_noisy, sr=sr, hop_length=hop_length)
    F = lb.feature.chroma_cqt(y_noisy, sr=sr, hop_length=hop_length, norm=2)
    np.save(outfile, F)
    return

# %%
def compute_chroma_AWGN_batch(filelist, outdir, n_cores, snr_db):
    
    # prep inputs for parallelization
    inputs = []
    with open(filelist, 'r') as f:
        for line in f:
            relpath = line.strip()
            reldir, fileid = os.path.split(relpath)
            featdir = outdir / reldir
            featdir.mkdir(parents=True, exist_ok=True)
            featfile = featdir / fileid
            audiofile = (AUDIO_ROOT / relpath).with_suffix('.wav')
            inputs.append((audiofile, featfile, snr_db))

    # process files in parallel
    pool = multiprocessing.Pool(processes = n_cores)
    pool.starmap(compute_chroma_AWGN_single, inputs)
    
    return

# %%
snrs = [20, 15, 10, 5, 0, -5]
for snr in snrs:
    print(f'Computing features at {snr}dB')
    featdir = FEATURES_ROOT / f'awgn{snr}dB'
    compute_chroma_AWGN_batch(train_files, featdir, 24, snr)
    compute_chroma_AWGN_batch(test_files, featdir, 24, snr)
# Out:
# Computing features at 20dB
# Computing features at 15dB
# Computing features at 10dB
# Computing features at 5dB
# Computing features at 0dB
# Computing features at -5dB

# %% [markdown]
# ### Generate query list

# %% [markdown]
# Here we generate a file containing each pair of files to be aligned.

# %%
def generate_query_list(filelist, outfile):
    
    # group files by piece
    d = {}
    with open(filelist, 'r') as f:
        for line in f:
            parts = line.strip().split('/')
            assert len(parts) == 2
            piece, fileid = parts
            if piece not in d:
                d[piece] = []
            d[piece].append(fileid)
            
    # print out all pairings
    with open(outfile, 'w') as fout:
        for piece in d:
            num_recordings = len(d[piece])
            for i in range(num_recordings):
                fileid1 = d[piece][i]
                for j in range(i+1, num_recordings):
                    fileid2 = d[piece][j]
                    line = f'{piece}/{fileid1} {piece}/{fileid2}\n'
                    fout.write(line)
                    
    return

# %%
train_queries = 'cfg_files/query.train.list'
test_queries = 'cfg_files/query.test.list'
generate_query_list(train_files, train_queries)
generate_query_list(test_files, test_queries)
